# %% [markdown]
# # Ecommerce Purchases Exercise
#
# In this Exercise you will be given some Fake Data about some purchases done through Amazon! Just go ahead and follow the directions and try your best to answer the questions and complete the tasks. Feel free to reference the solutions. Most of the tasks can be solved in different ways. For the most part, the questions get progressively harder.
#
# Please excuse anything that doesn't make "Real-World" sense in the dataframe, all the data is fake and made-up.
#
# Also note that all of these questions can be answered with one line of code.

# %%
# importing the libraries..

import numpy as np
import pandas as pd

# %%
# Loading the data in DataFrame.

df = pd.read_csv('Ecommerce Purchases')

# %%
df.head()
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
# 4  Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
# ...

# %%
df.describe()
# Out:
#         Credit Card  CC Security Code  Purchase Price
# count  1.000000e+04      10000.000000    10000.000000
# mean   2.341374e+15        907.217800       50.347302
# std    2.256103e+15       1589.693035       29.015836
# min    6.040186e+10          0.000000        0.000000
# 25%    3.056322e+13        280.000000       25.150000
# 50%    8.699942e+14        548.000000       50.505000
# 75%    4.492298e+15        816.000000       75.770000
# max    6.012000e+15       9993.000000       99.990000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Address           10000 non-null  object
#  1   Lot               10000 non-null  object
#  2   AM or PM          10000 non-null  object
#  3   Browser Info      10000 non-null  object
#  4   Company           10000 non-null  object
#  5   Credit Card       10000 non-null  int64
#  6   CC Exp Date       10000 non-null  object
#  7   CC Security Code  10000 non-null  int64
#  8   CC Provider       10000 non-null  object
#  9   Email             10000 non-null  object
#  10  Job               10000 non-null  object
#  11  IP Address        10000 non-null  object
#  12  Language          10000 non-null  object
#  13  Purchase Price    10000 non-null  float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 1.1+ MB

# %%
# Checking the languages spoken by the customers

df['Language'].unique()
# Out:
# array(['el', 'fr', 'de', 'es', 'ru', 'pt', 'zh', 'en', 'it'], dtype=object)

# %%
# Checking the english language spoken customer count.

df[df['Language']=='en'].count()
# Out:
# Address             1098
# Lot                 1098
# AM or PM            1098
# Browser Info        1098
# Company             1098
# Credit Card         1098
# CC Exp Date         1098
# CC Security Code    1098
# CC Provider         1098
# Email               1098
# Job                 1098
# IP Address          1098
# Language            1098
# Purchase Price      1098
# dtype: int64

# %%
df.head(30)   # checking the top 30 list in DataFrame..
# Out:
#                                               Address    Lot AM or PM  \
# 0   16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1   9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                    Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3               7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4   23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# 5   7502 Powell Mission Apt. 768\nTravisland, VA 3...  21 XT       PM
# 6      93971 Conway Causeway\nAndersonburgh, AZ 75107  96 Xt       AM
# 7   260 Rachel Plains Suite 366\nCastroberg, WV 24...  96 pG       PM
# 8             2129 Dylan Burg\nNew Michelle, ME 28650  45 JN       PM
# 9     3795 Dawson Extensions\nLake Tinafort, ID 88739  15 Ug       AM
# 10      650 Elizabeth Park\nLake Maria, LA 13526-2530  65 Yn       PM
# 11             349 Laurie Parks\nThomasview, ID 08970  30 kK       PM
# ...

# %%
df['Job'].value_counts()   # seems like there are various category of jobs customers are doing.
# Out:
# Interior and spatial designer    31
# Lawyer                           30
# Social researcher                28
# Purchasing manager               27
# Designer, jewellery              27
#                                  ..
# Prison officer                    7
# Editor, film/video                6
# Actuary                           6
# Information systems manager       5
# Investment analyst                5
# Name: Job, Length: 623, dtype: int64

# %%
df.columns  # here are all the columns of this dataset
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
# Checking how many customers were in the lawyer profession.

df[df['Job']=='Lawyer'].count()


# seems like there are very few in the lawyer position.
# Out:
# Address             30
# Lot                 30
# AM or PM            30
# Browser Info        30
# Company             30
# Credit Card         30
# CC Exp Date         30
# CC Security Code    30
# CC Provider         30
# Email               30
# Job                 30
# IP Address          30
# Language            30
# Purchase Price      30
# dtype: int64

# %%
df.columns  # here again we checking the dataset columns.
            # Sorry i have very poor memory storage in my brain....STML..ahh
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
# lets move ahead.

# %%
df['AM or PM'].value_counts()  # Seems like most of the customers do purchases after midnoon.
# Out:
# PM    5068
# AM    4932
# Name: AM or PM, dtype: int64

# %%
df['Job'].value_counts().head(5)   # here are the list of top 5 most choosen job profession by our customers

                                   # F%%%ing Rich! ahem..
# Out:
# Interior and spatial designer    31
# Lawyer                           30
# Social researcher                28
# Purchasing manager               27
# Designer, jewellery              27
# Name: Job, dtype: int64

# %% [markdown]
# ** Someone made a purchase that came from Lot: "90 WT" , what was the Purchase Price for this transaction? **

# %%
df[df['Lot']=='90 WT']['Purchase Price']   # just checking.....
# Out:
# 513    75.1
# Name: Purchase Price, dtype: float64

# %%
# So, here are the figure.shape.curve.size of the dataset....

df.shape
# Out:
# (10000, 14)

# %%
df.columns # ahmm. again here we go....
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %% [markdown]
# ** What is the email of the person with the following Credit Card Number: 4926535242672853 **

# %%
df[df['Credit Card']==4926535242672853]['Email']       # just spying......
# Out:
# 1234    bondellen@williams-garza.com
# Name: Email, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Address           10000 non-null  object
#  1   Lot               10000 non-null  object
#  2   AM or PM          10000 non-null  object
#  3   Browser Info      10000 non-null  object
#  4   Company           10000 non-null  object
#  5   Credit Card       10000 non-null  int64
#  6   CC Exp Date       10000 non-null  object
#  7   CC Security Code  10000 non-null  int64
#  8   CC Provider       10000 non-null  object
#  9   Email             10000 non-null  object
#  10  Job               10000 non-null  object
#  11  IP Address        10000 non-null  object
#  12  Language          10000 non-null  object
#  13  Purchase Price    10000 non-null  float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 1.1+ MB

# %%
# So! here is the the list of credit card provider 

df['CC Provider'].value_counts()
# Out:
# JCB 16 digit                   1716
# VISA 16 digit                  1715
# JCB 15 digit                    868
# American Express                849
# Maestro                         846
# Voyager                         829
# Discover                        817
# Mastercard                      816
# VISA 13 digit                   777
# Diners Club / Carte Blanche     767
# Name: CC Provider, dtype: int64

# %% [markdown]
# * How many people have American Express as their Credit Card Provider *and made a purchase above $95 ?**

# %%
df[(df['CC Provider']=='American Express') & (df['Purchase Price']>95)].count()  # hmm
# Out:
# Address             39
# Lot                 39
# AM or PM            39
# Browser Info        39
# Company             39
# Credit Card         39
# CC Exp Date         39
# CC Security Code    39
# CC Provider         39
# Email               39
# Job                 39
# IP Address          39
# Language            39
# Purchase Price      39
# dtype: int64

# %%
df.columns  # ...
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
df['CC Exp Date']
# Out:
# 0       02/20
# 1       11/18
# 2       08/19
# 3       02/24
# 4       10/25
#         ...
# 9995    03/22
# 9996    07/25
# 9997    05/21
# 9998    11/17
# 9999    02/19
# Name: CC Exp Date, Length: 10000, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Address           10000 non-null  object
#  1   Lot               10000 non-null  object
#  2   AM or PM          10000 non-null  object
#  3   Browser Info      10000 non-null  object
#  4   Company           10000 non-null  object
#  5   Credit Card       10000 non-null  int64
#  6   CC Exp Date       10000 non-null  object
#  7   CC Security Code  10000 non-null  int64
#  8   CC Provider       10000 non-null  object
#  9   Email             10000 non-null  object
#  10  Job               10000 non-null  object
#  11  IP Address        10000 non-null  object
#  12  Language          10000 non-null  object
#  13  Purchase Price    10000 non-null  float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 1.1+ MB

# %% [markdown]
# ** Hard: How many people have a credit card that expires in 2025? **

# %%
df[df['CC Exp Date'].apply(lambda exp: exp[3:])=='25'].count()
# Out:
# Address             1033
# Lot                 1033
# AM or PM            1033
# Browser Info        1033
# Company             1033
# Credit Card         1033
# CC Exp Date         1033
# CC Security Code    1033
# CC Provider         1033
# Email               1033
# Job                 1033
# IP Address          1033
# Language            1033
# Purchase Price      1033
# dtype: int64

# %% [markdown]
# ** Hard: What are the top 5 most popular email providers/hosts (e.g. gmail.com, yahoo.com, etc...) **

# %%
df['Email'].head(20)
# Out:
# 0                  pdunlap@yahoo.com
# 1                 anthony41@reed.com
# 2     amymiller@morales-harrison.com
# 3        brent16@olson-robinson.info
# 4        christopherwright@gmail.com
# 5                  ynguyen@gmail.com
# 6                 olivia04@yahoo.com
# 7               phillip48@parks.info
# 8               kdavis@rasmussen.com
# 9           qcoleman@hunt-huerta.com
# 10              ustewart@hotmail.com
# 11          johnnymiller@coleman.com
# 12                 tholt@hotmail.com
# 13               caitlin57@yahoo.com
# 14                  aburns@yahoo.com
# 15                amanda39@yahoo.com
# 16       griffincatherine@wilson.com
# 17            stacymitchell@hall.com
# 18                hannah63@yahoo.com
# 19              ruiznicole@gmail.com
# Name: Email, dtype: object

# %%
#  here are the top 5 most popular email providers/hosts 


df['Email'].apply(lambda x: x.lower().split('@')[1]).value_counts().head()
# Out:
# hotmail.com     1638
# yahoo.com       1616
# gmail.com       1605
# smith.com         42
# williams.com      37
# Name: Email, dtype: int64

# %% [markdown]
# #  And yet lot more to do......
