# %% [markdown]
# # This is a sales data of western countries available in open source...

# %% [markdown]
# # Let's Explore this data & play some graphs with some interesting insights...

# %% [markdown]
# For better understing try to read the charts....

# %% [markdown]
# Pay attention to details..

# %%
# these are the library we are going to use for this dataset.
# import other libraries further if needed..

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
# importing the CSV data file..

df = pd.read_csv('sales_data.csv',parse_dates=['Date'])

# %%
df.head()
# Out:
#         Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0 2013-11-26   26  November  2013            19     Youth (<25)
# 1 2015-11-26   26  November  2015            19     Youth (<25)
# 2 2014-03-23   23     March  2014            49  Adults (35-64)
# 3 2016-03-23   23     March  2016            49  Adults (35-64)
# 4 2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %% [markdown]
# Let's check some basic info about this dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113036 entries, 0 to 113035
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Date              113036 non-null  datetime64[ns]
#  1   Day               113036 non-null  int64
#  2   Month             113036 non-null  object
#  3   Year              113036 non-null  int64
#  4   Customer_Age      113036 non-null  int64
#  5   Age_Group         113036 non-null  object
#  6   Customer_Gender   113036 non-null  object
#  7   Country           113036 non-null  object
#  8   State             113036 non-null  object
#  9   Product_Category  113036 non-null  object
#  10  Sub_Category      113036 non-null  object
#  11  Product           113036 non-null  object
#  12  Order_Quantity    113036 non-null  int64
#  13  Unit_Cost         113036 non-null  int64
#  14  Unit_Price        113036 non-null  int64
#  15  Profit            113036 non-null  int64
# ...

# %%
# checking rows & columns
df.shape
# Out:
# (113036, 18)

# %%
df.describe()
# Out:
#                  Day           Year   Customer_Age  Order_Quantity  \
# count  113036.000000  113036.000000  113036.000000   113036.000000
# mean       15.665753    2014.401739      35.919212       11.901660
# std         8.781567       1.272510      11.021936        9.561857
# min         1.000000    2011.000000      17.000000        1.000000
# 25%         8.000000    2013.000000      28.000000        2.000000
# 50%        16.000000    2014.000000      35.000000       10.000000
# 75%        23.000000    2016.000000      43.000000       20.000000
# max        31.000000    2016.000000      87.000000       32.000000
#
#            Unit_Cost     Unit_Price         Profit           Cost  \
# count  113036.000000  113036.000000  113036.000000  113036.000000
# mean      267.296366     452.938427     285.051665     469.318695
# std       549.835483     922.071219     453.887443     884.866118
# min         1.000000       2.000000     -30.000000       1.000000
# ...

# %%
# null value checking
df.isnull().sum()
# Out:
# Date                0
# Day                 0
# Month               0
# Year                0
# Customer_Age        0
# Age_Group           0
# Customer_Gender     0
# Country             0
# State               0
# Product_Category    0
# Sub_Category        0
# Product             0
# Order_Quantity      0
# Unit_Cost           0
# Unit_Price          0
# Profit              0
# Cost                0
# Revenue             0
# dtype: int64

# %% [markdown]
# let the play begin.

# %% [markdown]
# --------------------------------------------------------------------------------------------------

# %%
df['Year'].value_counts()    #  this insight is plotted below..
# Out:
# 2014    29398
# 2016    29398
# 2013    24443
# 2015    24443
# 2012     2677
# 2011     2677
# Name: Year, dtype: int64

# %%
# Checking the sales over the year.

sns.set_style('whitegrid')
sns.countplot(df['Year'])
plt.title('Sales over the Year')
# Out:
# E:\Data Headquarters\Anaconda navigator\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Sales over the Year')

# %%
# checking the Customer age density or variation

sns.distplot(df['Customer_Age'])
plt.title('Customer age density distribution chart')
# Out:
# E:\Data Headquarters\Anaconda navigator\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Customer age density distribution chart')

# %%
# Here we checking the the gender ratio of the customers in this dataset..


df['Customer_Gender'].value_counts().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='Customer_Gender'>

# %%
df.head()
# Out:
#         Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0 2013-11-26   26  November  2013            19     Youth (<25)
# 1 2015-11-26   26  November  2015            19     Youth (<25)
# 2 2014-03-23   23     March  2014            49  Adults (35-64)
# 3 2016-03-23   23     March  2016            49  Adults (35-64)
# 4 2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %%
df['Age_Group'].value_counts()
# Out:
# Adults (35-64)          55824
# Young Adults (25-34)    38654
# Youth (<25)             17828
# Seniors (64+)             730
# Name: Age_Group, dtype: int64

# %%
# checking the customer age group and customer age alignment are correct or not....
# As a data scientist you need to varify the given data parameters always true...for accurate insights


sns.barplot(x='Age_Group',y='Customer_Age',data=df,hue='Customer_Gender')
# Out:
# <AxesSubplot:xlabel='Age_Group', ylabel='Customer_Age'>

# %%
# Customer age mean 

plt.figure(figsize=(15,3))
sns.boxplot(df['Customer_Age'])

plt.title('Customer Age Distribution')
# Out:
# E:\Data Headquarters\Anaconda navigator\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Customer Age Distribution')

# %%
df['State'].value_counts()  # lets plot this graph below
# Out:
# California             22450
# British Columbia       14116
# England                13620
# Washington             11264
# New South Wales        10412
# Victoria                6016
# Oregon                  5286
# Queensland              5220
# Saarland                2770
# Nordrhein-Westfalen     2484
# Hessen                  2384
# Seine (Paris)           2328
# Hamburg                 1836
# Seine Saint Denis       1684
# Nord                    1670
# South Australia         1564
# Bayern                  1426
# Hauts de Seine          1084
# Essonne                  994
# Yveline                  954
# Tasmania                 724
# Seine et Marne           394
# Moselle                  386
# Loiret                   382
# Val d'Oise               264
# Garonne (Haute)          208
# Brandenburg              198
# Val de Marne             158
# Charente-Maritime        148
# Somme                    134
# Loir et Cher             120
# Pas de Calais             90
# ...

# %%
plt.figure(figsize=(15,15))
sns.set_style('whitegrid')

ax = sns.countplot(y=df['State'])
ax = ax.bar_label(ax.containers[0])

plt.title('State wise Distribution')
# Out:
# Text(0.5, 1.0, 'State wise Distribution')

# %%
df.head()
# Out:
#         Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0 2013-11-26   26  November  2013            19     Youth (<25)
# 1 2015-11-26   26  November  2015            19     Youth (<25)
# 2 2014-03-23   23     March  2014            49  Adults (35-64)
# 3 2016-03-23   23     March  2016            49  Adults (35-64)
# 4 2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %%
df['Sub_Category'].value_counts()
# Out:
# Tires and Tubes      33870
# Bottles and Cages    15876
# Road Bikes           13430
# Helmets              12158
# Mountain Bikes        8854
# Jerseys               6010
# Caps                  4358
# Fenders               4032
# Touring Bikes         3698
# Gloves                2686
# Cleaners              1802
# Shorts                1794
# Hydration Packs       1334
# Socks                 1122
# Vests                  964
# Bike Racks             592
# Bike Stands            456
# Name: Sub_Category, dtype: int64

# %%
df['Product_Category'].value_counts().plot(kind='pie',autopct='%1.1f%%')
plt.title('Items In Product Category')
# Out:
# Text(0.5, 1.0, 'Items In Product Category')

# %%
# Grouping Product Category Wise.
cv = df.groupby('Product_Category')


profit_category = cv['Profit'].sum().index
profit_Values = cv['Profit'].sum().values


plt.pie(profit_Values,labels=profit_category,autopct='%1.1f%%')

plt.title('Profit Percentage in Product Category')
# Out:
# Text(0.5, 1.0, 'Profit Percentage in Product Category')

# %%
plt.figure(figsize=(20,4))
sns.boxplot(x='Profit',y='Product_Category',data=df)

plt.title('Profit Distribution in Product Category')
# Out:
# Text(0.5, 1.0, 'Profit Distribution in Product Category')

# %%
plt.figure(figsize=(12,3))
sns.set_style('whitegrid')

sns.scatterplot(y='Country',x='Revenue',data=df,hue='Product_Category',s=20)

plt.title('Country Wise Revenue Distribution')
# Out:
# Text(0.5, 1.0, 'Country Wise Revenue Distribution')

# %%
plt.figure(figsize=(20,15))
sns.set_style('whitegrid')

sns.scatterplot(y='State',x='Revenue',data=df,hue='Product_Category',s=20)

plt.title('State v/s Revenue Distribution')
# Out:
# Text(0.5, 1.0, 'State v/s Revenue Distribution')

# %%
df.head()
# Out:
#         Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0 2013-11-26   26  November  2013            19     Youth (<25)
# 1 2015-11-26   26  November  2015            19     Youth (<25)
# 2 2014-03-23   23     March  2014            49  Adults (35-64)
# 3 2016-03-23   23     March  2016            49  Adults (35-64)
# 4 2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %% [markdown]
# Lots of Data

# %%
plt.figure(figsize=(12,5))
sns.set_style('darkgrid')

sns.stripplot(y='Sub_Category',x='Revenue',data=df,s=8)

plt.title('Revenue V|S Product Sub Categories')
# Out:
# Text(0.5, 1.0, 'Revenue V|S Product Sub Categories')

# %%
df['Year'].value_counts()
# Out:
# 2014    29398
# 2016    29398
# 2013    24443
# 2015    24443
# 2012     2677
# 2011     2677
# Name: Year, dtype: int64

# %% [markdown]
# Let's plot this CHART below

# %%
plt.figure(figsize=(20,5))

sns.set_style('darkgrid')
sns.barplot(y='Revenue',x='Year',data=df)

plt.title('Yearly Revenue Distribution')
# Out:
# Text(0.5, 1.0, 'Yearly Revenue Distribution')

# %% [markdown]
# Yearly Revenue Share

# %%
plt.figure(figsize=(20,8))
sns.set_style('whitegrid')

ax = sns.barplot(x='Month',y='Revenue',data=df)
ax = ax.bar_label(ax.containers[0])

plt.title('Month V/S Revenue Distribution')
# Out:
# Text(0.5, 1.0, 'Month V/S Revenue Distribution')

# %% [markdown]
# Monthly Revenue distribution over the years.

# %%
df.head()
# Out:
#         Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0 2013-11-26   26  November  2013            19     Youth (<25)
# 1 2015-11-26   26  November  2015            19     Youth (<25)
# 2 2014-03-23   23     March  2014            49  Adults (35-64)
# 3 2016-03-23   23     March  2016            49  Adults (35-64)
# 4 2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %%
dataset_1 = df[['Product_Category','Sub_Category','Product','Order_Quantity']]
dataset_1
# Out:
#        Product_Category Sub_Category              Product  Order_Quantity
# 0           Accessories   Bike Racks  Hitch Rack - 4-Bike               8
# 1           Accessories   Bike Racks  Hitch Rack - 4-Bike               8
# 2           Accessories   Bike Racks  Hitch Rack - 4-Bike              23
# 3           Accessories   Bike Racks  Hitch Rack - 4-Bike              20
# 4           Accessories   Bike Racks  Hitch Rack - 4-Bike               4
# ...                 ...          ...                  ...             ...
# 113031         Clothing        Vests      Classic Vest, S               3
# 113032         Clothing        Vests      Classic Vest, M              22
# 113033         Clothing        Vests      Classic Vest, M              22
# 113034         Clothing        Vests      Classic Vest, L              24
# 113035         Clothing        Vests      Classic Vest, L              23
#
# [113036 rows x 4 columns]

# %% [markdown]
# # Get the sale with the highest Revenue

# %%
df[df['Revenue']==df['Revenue'].max()]
# Out:
#              Date  Day Month  Year  Customer_Age       Age_Group  \
# 112073 2015-07-24   24  July  2015            52  Adults (35-64)
#
#        Customer_Gender    Country       State Product_Category Sub_Category  \
# 112073               M  Australia  Queensland         Clothing        Vests
#
#                         Product  Order_Quantity  Unit_Cost  Unit_Price  \
# 112073  Touring-1000 Yellow, 50              29       1482        2384
#
#         Profit   Cost  Revenue
# 112073   15096  42978    58074

# %% [markdown]
# # And yet  more to do.......

# %%
#  let's make a GroupBy filter of Revenue share yearly and monthly.

meta_2 = df.groupby(by=['Month','Year']).sum()['Revenue'].unstack()
meta_2
# Out:
# Year            2011       2012       2013       2014       2015       2016
# Month
# April       698782.0   731005.0   476905.0  2204586.0   734608.0  2756864.0
# August      880037.0   927504.0  1763071.0        NaN  2140581.0        NaN
# December   1132666.0  1110101.0  2995953.0        NaN  3848211.0        NaN
# February    637598.0   642657.0   485405.0  1945487.0   679246.0  2444190.0
# January     675193.0   671695.0   435063.0  2003941.0   666938.0  2553065.0
# July        882219.0   863284.0  1230711.0   516887.0  1728398.0   499960.0
# June        658138.0   691871.0   534099.0  2786120.0   786480.0  3586300.0
# March       708517.0   740824.0   466940.0  2108212.0   714008.0  2608663.0
# May         734537.0   765660.0   589689.0  2587491.0   895043.0  3264343.0
# November    574498.0   601501.0  2232077.0        NaN  2836222.0        NaN
# October     696949.0   727918.0  2041128.0        NaN  2529084.0        NaN
# ...

# %% [markdown]
#     # In the year 2014 & 2016
#
# they have no records of sales in the last 5 months.
#
#    AUGUST, SEPTEMBER, OCTOBER, NOVEMBER, DECEMBER

# %%
plt.figure(figsize=(13,7))
sns.heatmap(meta_2,lw=0.1,annot=True,cmap='YlOrBr')

plt.title('Monthly V|S Yearly Revenue index')

# In the year "2015" month of "DECEMBER" looks like they have made the best Revenue.
# Out:
# Text(0.5, 1.0, 'Monthly V|S Yearly Revenue index')
